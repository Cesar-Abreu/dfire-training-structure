# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip -o '/content/drive/MyDrive/new_project/D-Fire.zip' -d '/content/D-Fire dataset'
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: /content/D-Fire dataset/train/labels/WEB04443.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04444.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04445.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04446.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04447.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04448.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04449.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04450.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04451.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04452.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04453.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04454.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04455.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04456.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04457.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04458.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04459.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04460.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04461.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04462.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04463.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04464.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04465.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04466.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04467.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04468.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04469.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04470.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04471.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04472.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04473.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04474.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04475.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04476.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04477.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04478.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04479.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04480.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04481.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04482.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04483.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04484.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04485.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04486.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04487.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04488.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04489.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04490.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04491.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04492.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04493.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04494.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04495.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04496.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04497.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04498.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04499.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04500.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04501.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04502.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04503.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04504.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04505.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04506.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04507.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04508.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04509.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04510.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04511.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04512.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04513.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04514.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04515.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04516.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04517.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04518.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04519.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04520.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04521.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04522.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04523.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04524.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04525.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04526.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04527.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04528.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04529.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04530.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04531.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04532.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04533.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04534.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04535.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04536.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04537.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04538.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04539.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04540.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04541.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04542.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04543.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04544.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04545.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04546.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04547.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04548.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04549.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04550.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04551.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04552.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04553.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04554.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04555.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04556.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04557.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04558.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04559.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04560.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04561.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04562.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04563.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04564.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04565.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04566.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04567.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04568.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04569.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04570.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04571.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04572.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04573.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04574.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04575.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04576.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04577.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04578.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04579.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04580.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04581.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04582.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04583.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04584.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04585.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04586.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04587.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04588.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04589.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04590.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04591.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04592.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04593.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04594.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04595.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04596.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04597.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04598.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04599.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04600.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04601.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04602.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04603.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04604.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04605.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04606.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04607.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04608.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04609.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04610.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04611.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04612.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04613.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04614.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04615.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04616.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04617.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04618.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04619.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04620.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04621.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04622.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04623.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04624.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04625.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04626.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04627.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04628.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04629.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04630.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04631.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04632.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04633.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04634.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04635.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04636.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04637.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04638.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04639.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04640.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04641.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04642.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04643.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04644.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04645.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04646.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04647.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04648.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04649.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04650.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04651.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04652.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04653.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04654.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04655.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04656.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04657.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04658.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04659.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04660.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04661.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04662.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04663.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04664.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04665.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04666.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04667.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04668.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04669.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04670.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04671.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04672.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04673.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04674.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04675.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04676.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04677.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04678.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04679.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04680.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04681.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04682.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04683.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04684.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04685.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04686.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04687.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04688.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04689.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04690.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04691.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04692.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04693.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04694.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04695.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04696.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04697.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04698.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04699.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04700.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04701.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04702.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04703.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04704.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04705.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04706.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04707.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04708.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04709.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04710.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04711.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04712.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04713.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04714.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04715.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04716.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04717.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04718.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04719.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04720.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04721.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04722.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04723.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04724.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04725.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04726.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04727.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04728.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04729.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04730.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04731.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04732.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04733.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04734.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04735.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04736.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04737.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04738.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04739.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04740.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04741.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04742.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04743.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04744.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04745.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04746.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04747.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04748.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04749.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04750.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04751.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04752.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04753.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04754.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04755.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04756.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04757.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04758.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04759.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04760.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04761.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04762.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04763.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04764.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04765.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04766.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04767.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04768.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04769.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04770.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04771.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04772.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04773.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04774.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04775.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04776.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04777.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04778.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04779.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04780.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04781.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04782.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04783.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04784.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04785.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04786.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04787.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04788.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04789.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04790.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04791.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04792.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04793.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04794.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04795.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04796.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04797.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04798.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04799.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04800.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04801.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04802.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04803.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04804.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04805.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04806.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04807.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04808.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04809.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04810.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04811.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04812.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04813.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04814.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04815.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04816.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04817.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04818.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04819.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04820.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04821.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04822.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04823.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04824.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04825.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04826.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04827.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04828.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04829.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04830.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04831.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04832.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04833.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04834.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04835.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04836.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04837.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04838.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04839.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04840.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04841.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04842.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04843.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04844.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04845.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04846.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04847.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04848.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04849.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04850.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04851.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04852.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04853.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04854.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04855.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04856.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04857.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04858.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04859.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04860.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04861.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04862.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04863.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04864.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04865.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04866.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04867.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04868.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04869.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04870.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04871.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04872.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04873.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04874.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04875.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04876.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04877.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04878.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04879.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04880.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04881.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04882.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04883.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04884.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04885.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04886.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04887.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04888.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04889.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04890.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04891.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04892.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04893.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04894.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04895.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04896.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04897.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04898.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04899.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04900.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04901.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04902.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04903.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04904.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04905.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04906.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04907.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04908.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04909.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04910.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04911.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04912.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04913.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04914.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04915.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04916.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04917.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04918.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04919.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04920.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04921.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04922.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04923.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04924.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04925.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04926.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04927.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04928.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04929.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04930.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04931.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04932.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04933.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04934.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04935.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04936.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04937.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04938.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04939.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04940.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04941.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04942.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04943.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04944.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04945.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04946.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04947.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04948.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04949.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04950.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04951.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04952.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04953.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04954.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04955.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04956.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04957.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04958.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04959.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04960.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04961.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04962.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04963.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04964.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04965.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04966.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04967.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04968.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04969.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04970.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04971.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04972.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04973.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04974.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04975.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04976.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04977.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04978.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04979.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04980.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04981.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04982.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04983.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04984.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04985.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04986.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04987.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04988.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04989.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04990.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04991.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04992.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04993.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04994.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04995.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04996.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04997.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04998.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB04999.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05000.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05001.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05002.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05003.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05004.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05005.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05006.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05007.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05008.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05009.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05010.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05011.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05012.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05013.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05014.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05015.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05016.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05017.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05018.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05019.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05020.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05021.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05022.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05023.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05024.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05025.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05026.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05027.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05028.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05029.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05030.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05031.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05032.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05033.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05034.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05035.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05036.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05037.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05038.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05039.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05040.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05041.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05042.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05043.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05044.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05045.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05046.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05047.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05048.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05049.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05050.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05051.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05052.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05053.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05054.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05055.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05056.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05057.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05058.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05059.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05060.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05061.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05062.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05063.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05064.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05065.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05066.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05067.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05068.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05069.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05070.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05071.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05072.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05073.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05074.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05075.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05076.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05077.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05078.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05079.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05080.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05081.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05082.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05083.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05084.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05085.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05086.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05087.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05088.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05089.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05090.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05091.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05092.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05093.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05094.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05095.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05096.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05097.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05098.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05099.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05100.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05101.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05102.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05103.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05104.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05105.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05106.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05107.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05108.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05109.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05110.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05111.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05112.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05113.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05114.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05115.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05116.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05117.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05118.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05119.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05120.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05121.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05122.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05123.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05124.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05125.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05126.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05127.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05128.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05129.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05130.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05131.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05132.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05133.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05134.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05135.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05136.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05137.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05138.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05139.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05140.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05141.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05142.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05143.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05144.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05145.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05146.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05147.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05148.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05149.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05150.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05151.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05152.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05153.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05154.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05155.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05156.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05157.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05158.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05159.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05160.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05161.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05162.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05163.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05164.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05165.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05166.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05167.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05168.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05169.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05170.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05171.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05172.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05173.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05174.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05175.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05176.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05177.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05178.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB05179.txt
# ...
#   inflating: /content/D-Fire dataset/train/labels/WEB09197.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09198.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09199.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09200.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09201.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09202.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09203.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09204.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09205.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09206.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09207.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09208.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09209.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09210.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09211.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09212.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09213.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09214.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09215.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09216.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09217.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09218.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09219.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09220.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09221.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09222.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09223.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09224.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09225.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09226.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09227.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09228.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09229.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09230.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09231.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09232.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09233.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09234.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09235.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09236.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09237.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09238.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09239.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09240.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09241.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09242.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09243.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09244.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09245.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09246.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09247.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09248.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09249.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09250.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09251.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09252.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09253.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09254.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09255.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09256.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09257.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09258.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09259.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09260.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09261.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09262.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09263.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09264.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09265.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09266.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09267.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09268.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09269.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09270.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09271.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09272.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09273.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09274.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09275.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09276.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09277.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09278.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09279.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09280.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09281.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09282.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09283.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09284.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09285.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09286.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09287.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09288.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09289.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09290.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09291.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09292.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09293.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09294.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09295.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09296.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09297.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09298.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09299.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09300.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09301.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09302.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09303.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09304.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09305.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09306.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09307.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09308.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09309.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09310.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09311.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09312.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09313.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09314.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09315.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09316.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09317.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09318.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09319.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09320.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09321.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09322.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09323.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09324.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09325.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09326.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09327.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09328.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09329.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09330.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09331.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09332.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09333.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09334.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09335.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09336.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09337.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09338.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09339.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09340.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09341.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09342.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09343.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09344.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09345.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09346.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09347.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09348.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09349.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09350.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09351.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09352.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09353.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09354.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09355.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09356.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09357.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09358.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09359.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09360.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09361.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09362.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09363.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09364.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09365.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09366.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09367.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09368.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09369.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09370.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09371.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09372.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09373.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09374.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09375.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09376.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09377.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09378.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09379.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09380.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09381.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09382.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09383.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09384.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09385.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09386.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09387.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09388.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09389.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09390.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09391.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09392.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09393.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09394.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09395.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09396.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09397.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09398.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09399.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09400.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09401.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09402.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09403.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09404.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09405.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09406.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09407.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09408.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09409.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09410.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09411.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09412.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09413.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09414.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09415.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09416.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09417.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09418.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09419.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09420.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09421.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09422.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09423.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09424.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09425.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09426.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09427.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09428.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09429.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09430.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09431.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09432.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09433.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09434.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09435.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09436.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09437.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09438.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09439.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09440.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09441.txt
#   inflating: /content/D-Fire dataset/train/labels/WEB09442.txt

# %%
# Download .yaml file
# !cp /content/drive/MyDrive/new_project/dfire_config.yaml /content/dfire_config.yaml

# %%
import os
import random
import shutil

random.seed(10)

train_images_folder = "D-Fire dataset/train/images"
train_labels_folder = "D-Fire dataset/train/labels"
val_images_folder = "D-Fire dataset/val/images"
val_labels_folder = "D-Fire dataset/val/labels"

# Create the validation folders if they don't exist
os.makedirs(val_images_folder, exist_ok=True)
os.makedirs(val_labels_folder, exist_ok=True)

# Get the list of image files in the train set
image_files = os.listdir(train_images_folder)

# Calculate the number of images to move to the validation set
num_val_images = int(0.1 * len(image_files))

# Randomly select the images to move
val_image_files = random.sample(image_files, num_val_images)

# Move the selected images and their corresponding labels to the validation set
for image_file in val_image_files:
   # Move image file
   image_src = os.path.join(train_images_folder, image_file)
   image_dst = os.path.join(val_images_folder, image_file)
   shutil.move(image_src, image_dst)

   # Move label file
   label_file = image_file.replace(".jpg", ".txt")
   label_src = os.path.join(train_labels_folder, label_file)
   label_dst = os.path.join(val_labels_folder, label_file)
   shutil.move(label_src, label_dst)

# %%
import numpy as np


def polynomial_space(x, X=None):
    """
    Construct a polynomial feature space from input vector x.

    Each column of the output corresponds to x raised to a power
    specified in X.

    Parameters
    ----------
    x : np.ndarray
        Input vector or matrix. If x is 1D, it is treated as a column vector.
    X : array-like, optional
        Sequence of exponents. If None, exponents range from
        0 to size(x, 0) - 1, matching the MATLAB default behavior.

    Returns
    -------
    Px : np.ndarray
        Polynomial space matrix where:
        Px[:, i] = x ** X[i]
    """
    x = np.asarray(x)

    # Ensure column vector behavior like MATLAB
    if x.ndim == 1:
        x = x.reshape(-1, 1)

    if X is None:
        X = np.arange(x.shape[0])

    X = np.asarray(X)
    Px = np.zeros((x.shape[0], len(X)), dtype=x.dtype)

    for i, exp in enumerate(X):
        Px[:, i] = np.power(x[:, 0], exp)

    return Px

# %%
import numpy as np


def truth_space(d, G):
    """
    Construct the truth space for a given depth and group size.

    This function generates all combinations of values in the range
    [0, G-1] with depth `d`, arranged to match the original MATLAB
    construction order.

    Parameters
    ----------
    d : int
        Depth of the truth space (number of variables).
    G : int
        Group size (number of discrete values per variable).

    Returns
    -------
    x : np.ndarray
        Matrix of shape (G**d, d) representing the truth space.
        If d == 0, returns an empty array.
    """
    if d == 0:
        return np.empty((0, 0), dtype=int)

    x = np.empty((0, 0), dtype=int)

    for id_ in range(d):
        xi = np.tile(np.arange(G), (G ** id_, 1))
        xi = xi.reshape(-1, 1)

        if x.size == 0:
            x = xi
        else:
            x = np.hstack([xi, np.tile(x, (G, 1))])

    return x

# %%
import numpy as np
from itertools import combinations
from math import ceil, log


def mai_train(xh, yh, options=None):
    """
    Train a Modular Artificial Intelligence (MAI) model.

    Parameters
    ----------
    xh : np.ndarray
        Input training samples of shape (S, N).
    yh : np.ndarray
        Output training samples of shape (S,).
    options : dict, optional
        Training options:
        - verbose (int)
        - refined (bool)
        - group_size (int)
        - check (bool)
        - modulus (int)
        - input_step (int)
        - best_error_reduction (bool)

    Returns
    -------
    model : dict
        Trained MAI model.
    info : dict
        Training information and statistics.
    """
    if options is None:
        options = {}

    options.setdefault("verbose", 0)
    options.setdefault("refined", True)
    options.setdefault("group_size", 2)
    options.setdefault("check", False)
    options.setdefault("modulus", 0)
    options.setdefault("input_step", 0)
    options.setdefault("best_error_reduction", True)

    # -----------------------------
    # Basic parameters
    # -----------------------------
    S, N = xh.shape
    Ns = options["input_step"] or N
    G = options["group_size"]

    M = next_prime(
        max(
            S,
            2 ** min(G, Ns),
            int(xh.max()) + 1,
            int(yh.max()) + 1,
        )
    )

    # -----------------------------
    # Fixed modulus refinement
    # -----------------------------
    if options["modulus"]:
        if options["modulus"] < M:
            Mp = options["modulus"]
            rmax = ceil(log(max(xh.max(), yh.max()) + 1) / log(Mp))
            M = Mp ** rmax

            refiners = []
            xhr = np.zeros((S, 0), dtype=int)

            for r in range(1, rmax + 1):
                refiners.append(
                    lambda x, r=r: np.floor(
                        (x * Mp ** (r - 1)) % M / ceil(M / Mp)
                    ).astype(int)
                )
                xhr = np.hstack([xhr, refiners[-1](xh)])

            options["input_step"] = N
            options["modulus"] = 0

            model, info = mai_train(xhr, yh, options)

            model["refiners"] = refiners
            model["infer"] = lambda x: model["decoder"](
                infer(
                    model["encoder"](x),
                    model["inputs"],
                    model["refiners"],
                    model["refined"],
                    model["parameters"],
                    model["exponents"],
                    options["group_size"],
                )
            )
            return model, info
        else:
            M = next_prime(options["modulus"])

    # -----------------------------
    # Encoding / decoding
    # -----------------------------
    xlim = (xh.min(), xh.max())
    if not np.all(xh.astype(int) == xh):
        encoder = lambda x: np.floor(
            (x - xlim[0]) / (xlim[1] - xlim[0]) * M
        ).astype(int)
    else:
        encoder = lambda x: x.astype(int)

    ylim = (yh.min(), yh.max())
    if not np.all(yh.astype(int) == yh):
        yh = np.floor(
            (yh - ylim[0]) / (ylim[1] - ylim[0]) * M
        ).astype(int)
        decoder = lambda y: y / (M - 1) * (ylim[1] - ylim[0]) + ylim[0]
    else:
        decoder = lambda y: y

    xh = modular_residue(encoder(xh), M)
    yh = modular_residue(yh, M)

    # -----------------------------
    # Initialization
    # -----------------------------
    Xh = [xh]
    ey = yh

    info = {
        "modulus": M,
        "samples": S,
        "grouping": G,
        "inputs": [],
        "groups": [],
        "parameters": [],
        "energy": 0,
        "error": [ey.residue.sum()],
    }

    model = {
        "parameters": modular_residue(np.zeros((S, 0)), M),
        "inputs": [[list(range(N))]],
        "refined": [[True] * N],
        "refiners": [],
        "exponents": np.arange(S),
        "encoder": encoder,
        "decoder": decoder,
        "error": ey,
        "cascade": Xh,
    }

    Ni = N

    # -----------------------------
    # Training loop
    # -----------------------------
    while Ni > 0:
        gmax = min(Ns, Ni, G)
        groups = list(combinations(range(Ni), gmax))
        info["groups"].append(len(groups))

        Xh.append(modular_residue(np.zeros((S, 0)), M))
        model["inputs"].append([])
        model["refined"].append([])

        info["parameters"].append(0)
        info["error"].append(ey.residue.sum())

        if options["verbose"]:
            print(f"\n{Ni:3d} inputs starting with error {info['error'][-1]:6d}")

        X = subsizes(M, gmax)
        xs = scale(Xh[-2].residue, M, X)

        for g in groups:
            xhe = group(xs[:, g], M, X)
            xhe, yhe = prune_error(xhe, ey)
            dy = yhe.residue.sum()

            if dy <= 0:
                continue

            P = polynomial_space(xhe, model["exponents"])
            w = np.linalg.lstsq(P, yhe.residue, rcond=None)[0]
            yw = (P @ w).astype(int)

            eyn = ey - yw
            err_new = eyn.residue.sum()

            if err_new < info["error"][-1]:
                ey = eyn
                Xh[-1] = np.column_stack([Xh[-1], yw])
                model["parameters"] = np.column_stack(
                    [model["parameters"], w]
                )
                model["inputs"][-1].append(list(g))
                model["refined"][-1].append(False)
                info["error"][-1] = err_new
                info["parameters"][-1] += np.count_nonzero(w)

            if err_new == 0:
                break

        info["inputs"].append(Xh[-1].shape[1])
        if info["error"][-1] == 0 or Ni == 1:
            break

        Ni = Xh[-1].shape[1]

    # -----------------------------
    # Final inference function
    # -----------------------------
    model["infer"] = lambda x: decoder(
        infer(
            encoder(x),
            model["inputs"],
            model["refiners"],
            model["refined"],
            model["parameters"],
            model["exponents"],
            options["group_size"],
        )
    )

    return model, info

# %%
def subsizes(M, N):
    """Return fair subsizes for modular grouping."""
    return int(M ** (1 / N))


def scale(x, M, X):
    """Scale modular inputs to group domain."""
    return np.floor(x / (M - 1) * X).astype(int)


def group(x, M, X):
    """Group variables into modular indices."""
    return modular_residue(subs2ind(X, x), M)


def subs2ind(S, I):
    """Convert subscripts to linear indices."""
    if np.isscalar(S):
        offsets = np.cumprod([1] + [S] * I.shape[1])
    else:
        offsets = np.cumprod([1] + list(S))

    idx = np.zeros(I.shape[0], dtype=int)
    for d in range(I.shape[1]):
        idx += I[:, d] * offsets[d]
    return idx


def prune_error(xh, yh):
    """Prune duplicated inputs keeping minimal error."""
    _, inv = np.unique(xh.residue, return_inverse=True)
    y = np.zeros(inv.max() + 1, dtype=int)
    for i in range(len(y)):
        y[i] = yh.residue[inv == i].min()
    return xh, modular_residue(y[inv], xh.modulus)

# %%
def is_prime(n):
    """
    Check whether a number is prime.

    Parameters
    ----------
    n : int

    Returns
    -------
    bool
        True if n is prime, False otherwise.
    """
    if n < 2:
        return False
    if n in (2, 3):
        return True
    if n % 2 == 0:
        return False
    i = 3
    while i * i <= n:
        if n % i == 0:
            return False
        i += 2
    return True

def next_prime(n, s=1):
    """
    Return the next prime number greater than or equal to `n`.

    The function increments the value by `s` until a prime number
    is found.

    Parameters
    ----------
    n : int
        Starting integer value.
    s : int, optional
        Step size used to increment `n` (default is 1).

    Returns
    -------
    int
        The first prime number p >= n such that p increases by steps of s.
    """
    p = int(n)
    while not is_prime(p):
        p += s
    return p

# %%
import os
import numpy as np
from imageio import imread
from math import atan2, degrees


def d_fire_train(folder="./", options=None):
    """
    Train a Modular Artificial Intelligence (MAI) model for the DIP angle dataset.

    This function loads paired image and label files, assembles them into
    modular input/output representations, and trains a MAI model.

    Parameters
    ----------
    folder : str, optional
        Path to the dataset folder containing images and labels.
    options : dict, optional
        Training options:
        - verbose (int): verbosity level
        - samples (int): maximum number of samples
        - size (tuple): expected image size (H, W, C)
        - modulus (int): modular arithmetic base

    Returns
    -------
    model : object
        Trained MAI model with an attached inference function.
    info : dict
        Training metadata and statistics.
    """
    if options is None:
        options = {}

    options.setdefault("verbose", 0)
    options.setdefault("samples", np.inf)
    options.setdefault("size", (64, 64, 3))
    options.setdefault("modulus", next_prime(255))

    label_extension = ".txt"
    image_extension = ".jpg"

    # Ensure trailing slash
    if not folder.endswith(os.sep):
        folder += os.sep

    # Match image and label files by name
    label_files = remove_extension(
        [f for f in os.listdir(folder) if f.endswith(label_extension)]
    )
    image_files = remove_extension(
        [f for f in os.listdir(folder) if f.endswith(image_extension)]
    )

    common = sorted(set(label_files).intersection(image_files))
    label_files = [folder + f + label_extension for f in common]
    image_files = [folder + f + image_extension for f in common]

    # Cardinalities
    S = int(min(options["samples"], len(label_files)))  # number of samples
    G = 2  # input group size
    M = next_prime(max(S, 2 ** G, 256))
    N = options["size"]

    # Dataset assembly
    xh = assemble_input(image_files[:S], M, N, options["verbose"])
    yh = assemble_output(label_files[:S], M, options["verbose"])

    # Training
    mai_options = {
        "verbose": options["verbose"],
        "modulus": M,
        "group_size": G,
    }

    model, info = mai_train(xh, yh, mai_options)

    # Attach inference helper
    model.infer_angle = lambda file: infer(file, model, M, N)
    info["images"] = len(image_files)

    return model, info


def remove_extension(files):
    """
    Remove file extensions from a list of filenames.

    Parameters
    ----------
    files : list of str
        Filenames with extensions.

    Returns
    -------
    list of str
        Filenames without extensions.
    """
    return [os.path.splitext(f)[0] for f in files]


def infer(file, model, M, N):
    """
    Infer the angle (in degrees) from a single image file.

    Parameters
    ----------
    file : str
        Path to the image file.
    model : object
        Trained MAI model.
    M : int
        Modulus used during training.
    N : tuple
        Expected image size.

    Returns
    -------
    float
        Estimated angle in degrees.
    """
    y = model.infer(assemble_input([file], M, N, verbose=0))
    return (y[0] / M) * 360.0


def assemble_input(files, M, N, verbose=0):
    """
    Convert image files into modular input vectors.

    Images are normalized, downsampled, centered, and flattened into
    fixed-size vectors suitable for MAI training.

    Parameters
    ----------
    files : list of str
        Paths to image files.
    M : int
        Modulus for quantization.
    N : tuple
        Target image size (H, W, C).
    verbose : int
        Verbosity level.

    Returns
    -------
    np.ndarray
        Input matrix of shape (samples, prod(N)).
    """
    if verbose:
        print("assembling input...", end="", flush=True)

    xh = np.zeros((len(files), np.prod(N)), dtype=int)

    for s, file in enumerate(files):
        image = imread(file).astype(float)
        image = np.floor(image / 255.0 * (M / (1 + np.finfo(float).eps)))

        # Downsample (equivalent to 1:4:end in MATLAB)
        image = image[::4, ::4, ...]

        if image.ndim == 2:
            image = image[:, :, np.newaxis]

        h, w, c = image.shape

        if c == 1 and N[2] > 1:
            image = np.repeat(image, N[2], axis=2)
            c = N[2]

        if N[2] == 1 and c > 1:
            image = np.round(image.mean(axis=2, keepdims=True))
            c = 1

        icon = np.zeros(N)

        if h <= N[0] and w <= N[1] and c <= N[2]:
            ih = slice((N[0] - h) // 2, (N[0] - h) // 2 + h)
            iw = slice((N[1] - w) // 2, (N[1] - w) // 2 + w)
            icon[ih, iw, :] = image

        xh[s, :] = icon.flatten()

    if verbose:
        print(" ok")

    return xh


def assemble_output(files, M, verbose=0):
    """
    Convert label files into modular output values.

    Each label file contains four integers defining two points.
    The angle between them is computed and mapped into modular space.

    Parameters
    ----------
    files : list of str
        Paths to label files.
    M : int
        Modulus for quantization.
    verbose : int
        Verbosity level.

    Returns
    -------
    np.ndarray
        Output vector of shape (samples,).
    """
    if verbose:
        print("assembling output...", end="", flush=True)

    yh = np.zeros(len(files), dtype=int)

    for s, file in enumerate(files):
        with open(file, "r") as f:
            C = np.array(list(map(int, f.read().split())))

        angle = degrees(atan2(C[1] - C[3], C[2] - C[0]))
        if angle < 0:
            angle += 360

        yh[s] = int(np.floor(angle / 360 * (M / (1 + np.finfo(float).eps))))

    if verbose:
        print(" ok")

    return yh

# %%
"""
Example script for training and using the DIP angle MAI model.
"""

def main():
    # --------------------------------------------------
    # Training options
    # --------------------------------------------------
    options = {
        "samples": 64,          # max number of training samples
        "verbose": 2,           # verbosity level
        "size": (32, 32, 1),    # image size (H, W, C)
        "modulus": 31,          # modular arithmetic base
    }

    dataset_folder = "/content/D-Fire dataset/train"

    # --------------------------------------------------
    # Train model
    # --------------------------------------------------
    model, info = d_fire_train(dataset_folder, options)

    print("\n=== Training info ===")
    print(info)

    # --------------------------------------------------
    # Inference on a single image
    # --------------------------------------------------
    test_image = "/content/D-Fire dataset/train/images/AoF00009.jpg"
    angle = model.infer_angle(test_image)

    print("\n=== Inference ===")
    print(f"Predicted angle: {angle:.2f} degrees")


if __name__ == "__main__":
    main()
# Out:
# assembling input... ok
# assembling output... ok
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-719476248.py in <cell line: 0>()
#      35
#      36 if __name__ == "__main__":
# ---> 37     main()
#
# /tmp/ipython-input-719476248.py in main()
#      19     # Train model
#      20     # --------------------------------------------------
# ---> 21     model, info = d_fire_train(dataset_folder, options)
#      22
#      23     print("\n=== Training info ===")
#
# /tmp/ipython-input-897942486.py in d_fire_train(folder, options)
#      74     }
#      75
# ---> 76     model, info = mai_train(xh, yh, mai_options)
#      77
#      78     # Attach inference helper
#
# /tmp/ipython-input-1923618817.py in mai_train(xh, yh, options)
#      53             S,
#      54             2 ** min(G, Ns),
# ---> 55             int(xh.max()) + 1,
#      56             int(yh.max()) + 1,
#      57         )
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _amax(a, axis, out, keepdims, initial, where)
#      42 def _amax(a, axis=None, out=None, keepdims=False,
#      43           initial=_NoValue, where=True):
# ---> 44     return umr_maximum(a, axis, None, out, keepdims, initial, where)
#      45
#      46 def _amin(a, axis=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation maximum which has no identity
